# %%
import duckdb
# Connect to local DB file
DB_PATH = "/Users/rajat/Documents/MyProjects/iCIMS-assignment/icims-de-assignment/icims.duckdb"
con = duckdb.connect(DB_PATH)
# Out:
# [(1,)]

# %%
df = con.execute("select * from applications").df()

# %%
display(df)
# Out:
#                             application_id  \
# 0     974a2447-ab73-460c-83f0-79b3f78ffd83
# 1     2a46cb32-439c-44f8-a93b-f044d2925f7c
# 2     75f32c8e-83fc-4a2b-8d0d-13d3779ee83d
# 3     288a2e51-d74d-430e-8e0f-6619692661f5
# 4     af314f40-5e8f-4d7e-bc36-c559156c992b
# ...                                    ...
# 4995  6c7f8ddd-bd13-4c10-b6d8-28f71ee41b8f
# 4996  a596371c-15b9-461e-9d2d-50858b5562ec
# 4997  e1f86345-1937-49e4-ab2a-f3aa769f047a
# 4998  6397a338-4364-47d4-a076-dd254fa181e9
# 4999  2391ab47-f15a-4799-a890-64e2deac7190
#
#                                     job_id  \
# 0     41dc1c60-a5f6-4735-b57b-6b29bb2aa146
# 1     ff6ef9ed-7e4c-429f-b8cb-ab4c97790e84
# 2     c8acffcf-a04d-4d14-997d-bae10bc2ea72
# 3     f64ab6ec-30a5-448e-afe9-b3d0363908bf
# 4     b674410d-d218-49d6-8093-bfb024e9bcfd
# ...                                    ...
# 4995  ad64b56c-610f-4a3f-b0bb-ac67aa38d0a1
# 4996  d1a7ba20-11b4-41e9-b15d-a72dd4cee27c
# 4997  5744f596-7422-4167-ab7a-2460604e46cb
# ...
